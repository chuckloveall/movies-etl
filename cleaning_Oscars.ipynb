# %%
import pandas as pd

# %%
oscar_csv = "Resources/the_oscar_award.csv"
oscar_df= pd.read_csv(oscar_csv)

# %%
oscar_df.columns
# Out:
# Index(['year_film', 'year_ceremony', 'ceremony', 'category', 'name', 'film',
#        'winner'],
#       dtype='object')

# %%
# oscar_renamed = oscar_df.rename(columns={'year_film': 'O_Year',
#                                          'category': 'O_Category',
#                                          'name': 'O_Nominee',
#                                          'film': 'O_Film Title',
#                                          'winner': 'O_Win'})
# oscar_renamed

# %%
# oscar_reduced = oscar_renamed[['O_Year', 'O_Category', 'O_Nominee', 'O_Film Title', 'O_Win']]
# oscar_reduced

# %%
oscar_df.dtypes
# Out:
# year_film         int64
# year_ceremony     int64
# ceremony          int64
# category         object
# name             object
# film             object
# winner             bool
# dtype: object

# %%
oscar_year = oscar_df.loc[(oscar_df['year_film'] >= 1970)]
oscar_year
# Out:
#        year_film  year_ceremony  ceremony                          category  \
# 4773        1970           1971        43                             ACTOR
# 4774        1970           1971        43                             ACTOR
# 4775        1970           1971        43                             ACTOR
# 4776        1970           1971        43                             ACTOR
# 4777        1970           1971        43                             ACTOR
# ...          ...            ...       ...                               ...
# 10390       2019           2020        92     WRITING (Original Screenplay)
# 10391       2019           2020        92  JEAN HERSHOLT HUMANITARIAN AWARD
# 10392       2019           2020        92                    HONORARY AWARD
# 10393       2019           2020        92                    HONORARY AWARD
# 10394       2019           2020        92                    HONORARY AWARD
#
# ...

# %%
oscar_year = oscar_year.dropna(how='any')
oscar_year
# Out:
#        year_film  year_ceremony  ceremony                       category  \
# 4773        1970           1971        43                          ACTOR
# 4774        1970           1971        43                          ACTOR
# 4775        1970           1971        43                          ACTOR
# 4776        1970           1971        43                          ACTOR
# 4777        1970           1971        43                          ACTOR
# ...          ...            ...       ...                            ...
# 10386       2019           2020        92  WRITING (Original Screenplay)
# 10387       2019           2020        92  WRITING (Original Screenplay)
# 10388       2019           2020        92  WRITING (Original Screenplay)
# 10389       2019           2020        92  WRITING (Original Screenplay)
# 10390       2019           2020        92  WRITING (Original Screenplay)
#
#                                                     name  \
# ...

# %%
# oscar_year.insert(0, 'Award Ceremony', 'Oscars')
# oscar_year

# %%
oscar_year.to_csv('Output/oscar_cleaned.csv', index=False, header=True)
