# %%
import pandas as pd

# %%
oscar_csv = "Resources/the_oscar_award.csv"
oscar_df= pd.read_csv(oscar_csv)

# %%
oscar_df.columns
# Out:
# Index(['year_film', 'year_ceremony', 'ceremony', 'category', 'name', 'film',
#        'winner'],
#       dtype='object')

# %%
oscar_renamed = oscar_df.rename(columns={'year_film': 'Year',
                                         'category': 'Award Category',
                                         'name': 'Nominee Name',
                                         'film': 'Film Title',
                                         'winner': 'Win'})
oscar_renamed
# Out:
#        Year  year_ceremony  ceremony                    Award Category  \
# 0      1927           1928         1                             ACTOR
# 1      1927           1928         1                             ACTOR
# 2      1927           1928         1                           ACTRESS
# 3      1927           1928         1                           ACTRESS
# 4      1927           1928         1                           ACTRESS
# ...     ...            ...       ...                               ...
# 10390  2019           2020        92     WRITING (Original Screenplay)
# 10391  2019           2020        92  JEAN HERSHOLT HUMANITARIAN AWARD
# 10392  2019           2020        92                    HONORARY AWARD
# 10393  2019           2020        92                    HONORARY AWARD
# 10394  2019           2020        92                    HONORARY AWARD
#
#                                             Nominee Name        Film Title  \
# ...

# %%
oscar_reduced = oscar_renamed[['Year', 'Award Category', 'Nominee Name', 'Film Title', 'Win']]
oscar_reduced
# Out:
#        Year                    Award Category  \
# 0      1927                             ACTOR
# 1      1927                             ACTOR
# 2      1927                           ACTRESS
# 3      1927                           ACTRESS
# 4      1927                           ACTRESS
# ...     ...                               ...
# 10390  2019     WRITING (Original Screenplay)
# 10391  2019  JEAN HERSHOLT HUMANITARIAN AWARD
# 10392  2019                    HONORARY AWARD
# 10393  2019                    HONORARY AWARD
# 10394  2019                    HONORARY AWARD
#
#                                             Nominee Name        Film Title  \
# 0                                    Richard Barthelmess         The Noose
# 1                                          Emil Jannings  The Last Command
# 2                                         Louise Dresser   A Ship Comes In
# 3                                           Janet Gaynor        7th Heaven
# ...

# %%
oscar_year = oscar_reduced.loc[(oscar_reduced['Year'] >= 1970)]
oscar_e
