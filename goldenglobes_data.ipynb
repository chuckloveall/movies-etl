# %%
import pandas as pd

# %%
#Create reference to CSV file
golden_globes_csv="Resources/golden_globe_awards.csv"

# %%
df=pd.read_csv(golden_globes_csv)

# %%
#preview data frame
df.head()
# Out:
#    year_film  year_award  ceremony  \
# 0       1943        1944         1
# 1       1943        1944         1
# 2       1943        1944         1
# 3       1943        1944         1
# 4       1943        1944         1
#
#                                             category                 nominee  \
# 0  Best Performance by an Actress in a Supporting...          Katina Paxinou
# 1  Best Performance by an Actor in a Supporting R...           Akim Tamiroff
# 2                     Best Director - Motion Picture              Henry King
# 3                                            Picture  The Song Of Bernadette
# 4                          Actress In A Leading Role          Jennifer Jones
#
#                       film   win
# 0  For Whom The Bell Tolls  True
# 1  For Whom The Bell Tolls  True
# 2   The Song Of Bernadette  True
# 3                      NaN  True
# 4   The Song Of Bernadette  True

# %%
#identify incomplete rows
df.count()
# Out:
# year_film     7991
# year_award    7991
# ceremony      7991
# category      7991
# nominee       7991
# film          6191
# win           7991
# dtype: int64

# %%
#drop all rows with incomplete info
df = df.dropna(how='any')

# %%
#verify dropped rows
df.count()
# Out:
# year_film     6191
# year_award    6191
# ceremony      6191
# category      6191
# nominee       6191
# film          6191
# win           6191
# dtype: int64

# %%
df.dtypes
# Out:
# year_film      int64
# year_award     int64
# ceremony       int64
# category      object
# nominee       object
# film          object
# win             bool
# dtype: object

# %%
df['year_film'].value_counts()
# Out:
# 1972    112
# 1982    112
# 1976    105
# 1999    104
# 2001    103
#        ...
# 1948     11
# 1946      7
# 1945      6
# 1943      5
# 1944      5
# Name: year_film, Length: 77, dtype: int64

# %%
updated_gg_df=df[df['year_film']>=1970]
updated_gg_df
# Out:
#       year_film  year_award  ceremony  \
# 1641       1970        1971        28
# 1642       1970        1971        28
# 1643       1970        1971        28
# 1644       1970        1971        28
# 1645       1970        1971        28
# ...         ...         ...       ...
# 7984       2019        2020        77
# 7985       2019        2020        77
# 7986       2019        2020        77
# 7987       2019        2020        77
# 7988       2019        2020        77
#
#                                                category            nominee  \
# 1641  Best Performance by an Actress in a Motion Pic...        Ali MacGraw
# 1642  Best Performance by an Actress in a Motion Pic...       Faye Dunaway
# 1643  Best Performance by an Actress in a Motion Pic...     Glenda Jackson
# 1644  Best Performance by an Actress in a Motion Pic...    Melina Mercouri
# 1645  Best Performance by an Actress in a Motion Pic...        Sarah Miles
# ...

# %%
updated_gg_df.insert(0, 'Award Ceremony', 'Golden Globes', allow_duplicates=True)
updated_gg_df
# Out:
#      Award Ceremony  year_film  year_award  ceremony  \
# 1641  Golden Globes       1970        1971        28
# 1642  Golden Globes       1970        1971        28
# 1643  Golden Globes       1970        1971        28
# 1644  Golden Globes       1970        1971        28
# 1645  Golden Globes       1970        1971        28
# ...             ...        ...         ...       ...
# 7984  Golden Globes       2019        2020        77
# 7985  Golden Globes       2019        2020        77
# 7986  Golden Globes       2019        2020        77
# 7987  Golden Globes       2019        2020        77
# 7988  Golden Globes       2019        2020        77
#
#                                                category            nominee  \
# 1641  Best Performance by an Actress in a Motion Pic...        Ali MacGraw
# 1642  Best Performance by an Actress in a Motion Pic...       Faye Dunaway
# 1643  Best Performance by an Actress in a Motion Pic...     Glenda Jackson
# ...
